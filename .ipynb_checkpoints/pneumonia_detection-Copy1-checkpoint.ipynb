# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras import models, Input, layers
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
def create_datasets(directory):
    labels = ['NORMAL', 'PNEUMONIA']
    images = [];
    diagnosis = [];
    for label in labels:
        path = os.path.join(directory, label)
        for img in os.listdir(path):
            img_path = os.path.join(path, img)
            np_img = cv2.imread(img_path)
            np_img = cv2.resize(np_img, (150, 150))
            images.append(np_img)
            diagnosis.append(labels.index(label))
    images = np.array(images)
    diagnosis = np.array(diagnosis)
    return images, diagnosis

# %%
X_train, y_train = create_datasets("../Pneumonia Detection/chest_xray/train")
X_test, y_test = create_datasets("../Pneumonia Detection/chest_xray/test")
X_val, y_val = create_datasets("../Pneumonia Detection/chest_xray/val")

# %%
X_train.shape
# Out:
# (5216, 150, 150, 3)

# %%
X_test.shape
# Out:
# (624, 150, 150, 3)

# %%
def rand_display(X, y):
    rand_index = random.randint(0, X.shape[0]-1)
    img = X[rand_index]
    title = y[rand_index]
    if (title == 0):
        title = 'NORMAL'
    else:
        title = 'PNEUMONIA'    
    plt.imshow(img)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
for i in range(5):
    rand_display(X_train, y_train)

# %%
normal_count = np.count_nonzero(y_train == 0)
pneumonia_count = np.count_nonzero(y_train == 1)
plt.bar(["NORMAL", "PNEUMONIA"], [normal_count, pneumonia_count])
plt.show()

# %%
X_train = X_train / 255.
X_train = np.reshape(X_train, (-1, 150, 150, 3))

X_test = X_test / 255.
X_test = np.reshape(X_test, (-1, 150, 150, 3))

X_val = X_val / 255.
X_val = np.reshape(X_val, (-1, 150, 150, 3))

# %%
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal_and_vertical", input_shape=(150, 150, 3)),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomTranslation(height_factor=0.2, width_factor=0.2)
  ])

# %%
adf = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 adf = ImageDataGenerator(
#       2     rotation_range=20,
#       3     width_shift_range=0.2,
#       4     height_shift_range=0.2,
#       5     horizontal_flip=True,
#       6     fill_mode='nearest'
#       7 )
#
# NameError: name 'ImageDataGenerator' is not defined

# %%
model = models.Sequential([
    data_augmentation,
    layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),
    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),
    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(2, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_9 (Sequential)            │ (None, 150, 150, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 150, 150, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 75, 75, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 75, 75, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 75, 75, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_13 (MaxPooling2D)      │ (None, 37, 37, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 37, 37, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 37, 37, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_14 (MaxPooling2D)      │ (None, 18, 18, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 18, 18, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 20736)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 128)                 │       2,654,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,710,914 (10.34 MB)
#  Trainable params: 2,710,914 (10.34 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=5, 
                    validation_data=(X_val, y_val),
                    callbacks=[early_stopping])
# Out:
# Epoch 1/5
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 58s 336ms/step - accuracy: 0.7184 - loss: 0.7317 - val_accuracy: 0.5000 - val_loss: 0.7024
# Epoch 2/5
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 54s 332ms/step - accuracy: 0.7382 - loss: 0.5273 - val_accuracy: 0.5000 - val_loss: 0.7795
# Epoch 3/5
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 54s 332ms/step - accuracy: 0.7307 - loss: 0.5007 - val_accuracy: 0.5000 - val_loss: 0.7698
# Epoch 4/5
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 53s 328ms/step - accuracy: 0.7421 - loss: 0.5024 - val_accuracy: 0.5000 - val_loss: 0.7905
# Epoch 5/5
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 54s 332ms/step - accuracy: 0.7432 - loss: 0.4841 - val_accuracy: 0.5625 - val_loss: 0.7917

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(X_val,  y_val, verbose=2)
# Out:
# 1/1 - 0s - 61ms/step - accuracy: 0.5000 - loss: 0.7024

# %%
test_acc

# %% [markdown]
# TODO: fix overfitting and do analysis
